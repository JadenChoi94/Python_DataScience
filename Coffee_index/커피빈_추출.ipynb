# %%
https://www.ediya.com/contents/find_store.html

# %%
from bs4 import BeautifulSoup
import requests
import json
import pandas as pd
from pandas.io.json import json_normalize

# %%
page = open("BEAN_KOREA.html",'r',  encoding='UTF8').read()
soup = BeautifulSoup(page, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!-- saved from url=(0047)https://www.coffeebeankorea.com/store/store.asp -->
# <html class="js canvas canvastext no-touch geolocation postmessage indexeddb hashchange history draganddrop websockets rgba hsla multiplebgs backgroundsize borderradius boxshadow textshadow opacity cssanimations cssgradients cssreflections csstransforms csstransforms3d csstransitions fontface generatedcontent video audio localstorage sessionstorage webworkers applicationcache svg inlinesvg" lang="ko-KR" style="">
#  <!--<![endif]-->
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <script async="" src="./BEAN_KOREA_files/kakao.min.js.다운로드">
#   </script>
#   <script async="" src="./BEAN_KOREA_files/analytics.js.다운로드">
#   </script>
#   <script async="" src="./BEAN_KOREA_files/linkid.js.다운로드" type="text/javascript">
#   </script>
#   <meta content="IE=edge, chrome=1" http-equiv="X-UA-Compatible"/>
#   <title>
#    STORE | COFFEE BEAN KOREA
# ...

# %%
soup.body
# Out:
# <body>
# <!--  start of : skipNavi -->
# <ul id="skipNavi">
# <li><a href="https://www.coffeebeankorea.com/store/store.asp#contents">본문내용 바로가기</a></li>
# <li><a href="https://www.coffeebeankorea.com/store/store.asp#footer">하단메뉴 바로가기</a></li>
# </ul>
# <!-- //end of  skipNavi -->
# <!--MOBILE GNB-->
# <div class="gnb_m" style="left: -380px;">
# <form action="javascript:searchRun();" autocomplete="off" method="get" name="searchForm">
# <fieldset>
# <legend class="hidden">검색 폼</legend>
# <input class="inp_search" id="searchItem" name="searchItem" onfocus="if(this.value=='' || this.value=='검색어를 입력하세요'){this.value='';}" type="text" value="검색어를 입력하세요"/>
# <button onclick="javascript:searchRun();void(0);">SEARCH</button>
# </fieldset>
# </form>
# <a class="btn_login" href="https://www.coffeebeankorea.com/member/login.asp#loginArea">로그인</a>
# <div class="select_style select_box no_over">
# <a class="select_a" href="javascript:void(0);">고객서비스</a>
# <ul>
# ...

# %%
soup.find_all('p')#모든p태그, 리스트로 넘어온다
# Out:
# [<p class="h_mbr_no_txt">
#  <strong class="pcolor4">로그인</strong>을 하시면 커피빈 멤버스 클럽의 <br class="d_hidden t_hidden"/><strong class="pcolor4">다양한혜택</strong>을 받으실 수 있습니다.
#  					</p>,
#  <p class="name"> <span>삼성봉은사거리점<strong class="distance">34m</strong></span> <a class="btn_style6" href="javascript:storePop2('31');void(0);">자세히보기</a> </p>,
#  <p class="tag"> <span class="decaf" title="디카페인">디카페인</span><span class="soy" title="두유">두유</span><span class="parking" title="주차가능">주차가능</span><span class="wifi" title="와이파이">와이파이</span><span class="smoking" title="흡연가능">흡연가능</span><span class="capsule" title="캡슐판매">캡슐판매</span><!--span class='cake' title='케익수령'>케익수령</span--> </p>,
#  <p class="address"> <span>서울시 강남구 영동대로 607 12번지 1,2층</span><!--span class="lot"><#StoreAddress2#></span--> </p>,
#  <p class="tel"><a href="tel:02-3443-5618">02-3443-5618</a></p>,
# ...

# %%
soup.find_all('p', class_='address')
# Out:
# [<p class="address"> <span>서울시 강남구 영동대로 607 12번지 1,2층</span><!--span class="lot"><#StoreAddress2#></span--> </p>,
#  <p class="address"> <span>서울시 강남구 봉은사로 524 코엑스 인터컨티넨탈아케이드</span><!--span class="lot"><#StoreAddress2#></span--> </p>,
#  <p class="address"> <span>서울 강남구 영동대로 513 컨벤션별관A동 지하 2층</span><!--span class="lot"><#StoreAddress2#></span--> </p>,
#  <p class="address"> <span>서울시 강남구 봉은사로 628 엘슨빌딩1층</span><!--span class="lot"><#StoreAddress2#></span--> </p>,
#  <p class="address"> <span>서울시 강남구 테헤란로87길 36 공항타워 1층</span><!--span class="lot"><#StoreAddress2#></span--> </p>,
#  <p class="address"> <span>서울시 강남구 영동대로 513 코엑스몰내지하2층</span><!--span class="lot"><#StoreAddress2#></span--> </p>,
#  <p class="address"> <span>서울시 강남구 영동대로 511 트레이드타워 지하1층</span><!--span class="lot"><#StoreAddress2#></span--> </p>,
#  <p class="address"> <span>서울시 강남구 테헤란로87길22 도심공항터미널 지하1층</span><!--span class="lot"><#StoreAddress2#></span--> </p>,
# ...

# %%
id="storeLocal"

# %%
soup.find_all(data-default="서울")
# Out:
#   File "<ipython-input-52-3e8e5a0a6162>", line 1
#     soup.find_all(data-default="서울")
#                  ^
# SyntaxError: keyword can't be an expression

# %%
from urllib.request import urlopen

# %%
url = "https://www.coffeebeankorea.com/store/store.asp"
page = urlopen(url)

soup = BeautifulSoup(page, "html.parser")

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if IE 6]> <html class="no-js lt-ie10 lt-ie9 lt-ie8 ie6" lang="ko-KR"> <![endif]-->
# <!--[if IE 7]> <html class="no-js lt-ie10 lt-ie9 lt-ie8 ie7" lang="ko-KR"> <![endif]-->
# <!--[if IE 8]> <html class="no-js lt-ie10 lt-ie9 ie8" lang="ko-KR"> <![endif]-->
# <!--[if IE 9]> <html class="no-js lt-ie10 ie9" lang="ko-KR"> <![endif]-->
# <!--[if gt IE 9]><!-->
# <html class="no-js" lang="ko-KR">
#  <!--<![endif]-->
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge, chrome=1" http-equiv="X-UA-Compatible"/>
#   <title>
#    STORE | COFFEE BEAN KOREA
#   </title>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no, target-densitydpi=medium-dpi" name="viewport"/>
#   <link href="/images/favicon.ico?v=1" rel="shortcut icon" type="image/x-icon"/>
#   <link href="/css/pages/import.css?v=20170406" rel="stylesheet"/>
#   <script src="/js/common/libs/modernizr.custom.js">
#   </script>
# ...

# %%
soup.find_all('p', 'address')[0].string

# %%
url = 'https://www.coffeebeankorea.com/store/store.asp'
r = requests.post(url)

r.text[:1000] # 수신된 데이터의 앞부분만 확인
# Out:
# '<!DOCTYPE html>\r\n\r\n<!--[if IE 6]> <html class="no-js lt-ie10 lt-ie9 lt-ie8 ie6" lang="ko-KR"> <![endif]-->\r\n<!--[if IE 7]> <html class="no-js lt-ie10 lt-ie9 lt-ie8 ie7" lang="ko-KR"> <![endif]-->\r\n<!--[if IE 8]> <html class="no-js lt-ie10 lt-ie9 ie8" lang="ko-KR"> <![endif]-->\r\n<!--[if IE 9]> <html class="no-js lt-ie10 ie9" lang="ko-KR"> <![endif]-->\r\n<!--[if gt IE 9]><!--> <html class="no-js" lang="ko-KR"> <!--<![endif]-->\r\n<head>\r\n\r\n\t<meta charset="UTF-8">\r\n\t<meta http-equiv="X-UA-Compatible" content="IE=edge, chrome=1">\r\n\r\n<title>STORE | COFFEE BEAN KOREA</title><meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no, target-densitydpi=medium-dpi">\r\n<link rel="shortcut icon" type="image/x-icon" href="/images/favicon.ico?v=1" />\r\n\r\n\t<link rel="stylesheet" href="/css/pages/import.css?v=20170406">\r\n\t<script src="/js/common/libs/modernizr.custom.js"></script>\t\r\n\t<script src="/
# ...
