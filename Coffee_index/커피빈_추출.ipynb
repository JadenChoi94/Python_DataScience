# %%
https://www.ediya.com/contents/find_store.html

# %%
from bs4 import BeautifulSoup
import requests
import json
import pandas as pd
from pandas.io.json import json_normalize

# %%
page = open("BEAN_KOREA.html",'r',  encoding='UTF8').read()
soup = BeautifulSoup(page, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!-- saved from url=(0047)https://www.coffeebeankorea.com/store/store.asp -->
# <html class="js canvas canvastext no-touch geolocation postmessage indexeddb hashchange history draganddrop websockets rgba hsla multiplebgs backgroundsize borderradius boxshadow textshadow opacity cssanimations cssgradients cssreflections csstransforms csstransforms3d csstransitions fontface generatedcontent video audio localstorage sessionstorage webworkers applicationcache svg inlinesvg" lang="ko-KR" style="">
#  <!--<![endif]-->
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <script async="" src="./BEAN_KOREA_files/kakao.min.js.다운로드">
#   </script>
#   <script async="" src="./BEAN_KOREA_files/analytics.js.다운로드">
#   </script>
#   <script async="" src="./BEAN_KOREA_files/linkid.js.다운로드" type="text/javascript">
#   </script>
#   <meta content="IE=edge, chrome=1" http-equiv="X-UA-Compatible"/>
#   <title>
#    STORE | COFFEE BEAN KOREA
# ...

# %%
soup.body
# Out:
# <body>
# <!--  start of : skipNavi -->
# <ul id="skipNavi">
# <li><a href="https://www.coffeebeankorea.com/store/store.asp#contents">본문내용 바로가기</a></li>
# <li><a href="https://www.coffeebeankorea.com/store/store.asp#footer">하단메뉴 바로가기</a></li>
# </ul>
# <!-- //end of  skipNavi -->
# <!--MOBILE GNB-->
# <div class="gnb_m" style="left: -380px;">
# <form action="javascript:searchRun();" autocomplete="off" method="get" name="searchForm">
# <fieldset>
# <legend class="hidden">검색 폼</legend>
# <input class="inp_search" id="searchItem" name="searchItem" onfocus="if(this.value=='' || this.value=='검색어를 입력하세요'){this.value='';}" type="text" value="검색어를 입력하세요"/>
# <button onclick="javascript:searchRun();void(0);">SEARCH</button>
# </fieldset>
# </form>
# <a class="btn_login" href="https://www.coffeebeankorea.com/member/login.asp#loginArea">로그인</a>
# <div class="select_style select_box no_over">
# <a class="select_a" href="javascript:void(0);">고객서비스</a>
# <ul>
# ...

# %%
from urllib.request import urlopen

# %%
from bs4 import BeautifulSoup
import requests
import json
import pandas as pd
from pandas.io.json import json_normalize

# %%
https://www.coffeebeankorea.com/store/store_data2.asp?lat=&lng=&chk1=0&chk2=0&chk3=0&chk4=0&chk5=0&chk6=0&chk7=0&chk8=0&chk9=0&keyword=&StoreLocal=%EC%84%9C%EC%9A%B8&StoreLocal2=&storeNo=

# %%
# parser.py
import requests
from bs4 import BeautifulSoup
import json
import os

BASE_DIR = os.path.dirname(os.path.abspath(__file__))

# HTTP GET Request
req = requests.get('https://www.coffeebeankorea.com/store/store_local_data.asp')

# HTML 소스 가져오기
html = req.text

soup = BeautifulSoup(html, 'html.parser')

#storeListUL > li:nth-child(1) > div.store_txt > p.address > span

my_titles = soup.select(
    'p > span'
    )
data = {}

for title in my_titles:
    data[title.text] = title.get('href')

with open(os.path.join(BASE_DIR, 'result.json'), 'w+') as json_file:
    json.dump(data, json_file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-63eea1632fa2> in <module>
#       5 import os
#       6
# ----> 7 BASE_DIR = os.path.dirname(os.path.abspath(__file__))
#       8
#       9 # HTTP GET Request
#
# NameError: name '__file__' is not defined

# %%
import requests
import json
import pandas as pd
from pandas.io.json import json_normalize

data = {
    'StoreLAT': '37.48669594836945', # 지정한 위도와 경도에서 가까운 순으로 나열
    'StoreLNG':'127.01053356053066',
    'StoreNo':'', # 01=서울시, 08=경기 ... 16=제주
    # 세부지역 (지정하지 않으면 시/도 전체)
    'StoreName':'',
    'StoreTel':'',
    'sort': '1',
}
    
url = 'https://www.coffeebeankorea.com/store/store_data2.asp?lat=&lng=&chk1=0&chk2=0&chk3=0&chk4=0&chk5=0&chk6=0&chk7=0&chk8=0&chk9=0&keyword=&StoreLocal=%EC%84%9C%EC%9A%B8&StoreLocal2=&storeNo='
r = requests.post(url, data=data)

r.text[:1000]
# Out:
# "[{  StoreNo : '341', StoreName : '서초동점', StoreTel : '02-3665-9507', StoreAddress : '서울특별시 서초구 반포대로70' , StoreOpendate : '월 - 금  07:30~22:00 | 주말/공휴일 08:00~22:00' , StoreLAT : '37.48669594836945', StoreLNG : '127.01053356053066', StoreShortDesc : '', StoreEmail : 'cbk431@coffeebeankorea.com' , StoreDecaffeine : '1' , StoreSoymilk : '1', StoreWifi : '1', StoreParking : '0', Storesmoking : '1' , StoreMachine : '0' , StoreCapsule : '1', StoreCake : '1', StoreDrive : '0', Distant : '', sort : '1' , StoreImage1 : '1_80.jpg', StoreImage2 : '신규매장_1.jpg', StoreImage3 : '3_75.jpg', StoreImage4 : '4_67.jpg', StoreImage5 : '5_47.jpg' , StoreImage6 : '6_8.jpg' },{  StoreNo : '336', StoreName : '교대법원점', StoreTel : '02- 3664-7716  ', StoreAddress : '서울 서초구 서초중앙로 156, 1층' , StoreOpendate : '월 - 금  07:30~23:00 | 주말/공휴일 08:00~23:00' , StoreLAT : '37.49563363637424', StoreLNG : '127.01353830115815', StoreShortDesc : '주차정보<br/>최초 30분 3천원<br/>이후 10분당 1천원', StoreEmail : 'cbk426@coffeebeankorea.com' , Sto
# ...

# %%
goo=r.text

# %%
# JSON 인코딩
jsonString = json.dumps(r.text, ensure_ascii=False)
 
# 문자열 출력
print(jsonString)
print(type(jsonString))   # class str
# Out:
# "[{  StoreNo : '341', StoreName : '서초동점', StoreTel : '02-3665-9507', StoreAddress : '서울특별시 서초구 반포대로70' , StoreOpendate : '월 - 금  07:30~22:00 | 주말/공휴일 08:00~22:00' , StoreLAT : '37.48669594836945', StoreLNG : '127.01053356053066', StoreShortDesc : '', StoreEmail : 'cbk431@coffeebeankorea.com' , StoreDecaffeine : '1' , StoreSoymilk : '1', StoreWifi : '1', StoreParking : '0', Storesmoking : '1' , StoreMachine : '0' , StoreCapsule : '1', StoreCake : '1', StoreDrive : '0', Distant : '', sort : '1' , StoreImage1 : '1_80.jpg', StoreImage2 : '신규매장_1.jpg', StoreImage3 : '3_75.jpg', StoreImage4 : '4_67.jpg', StoreImage5 : '5_47.jpg' , StoreImage6 : '6_8.jpg' },{  StoreNo : '336', StoreName : '교대법원점', StoreTel : '02- 3664-7716  ', StoreAddress : '서울 서초구 서초중앙로 156, 1층' , StoreOpendate : '월 - 금  07:30~23:00 | 주말/공휴일 08:00~23:00' , StoreLAT : '37.49563363637424', StoreLNG : '127.01353830115815', StoreShortDesc : '주차정보<br/>최초 30분 3천원<br/>이후 10분당 1천원', StoreEmail : 'cbk426@coffeebeankorea.com' , Sto
# ...

# %%
dict = json.loads(jsonString)

# %%
df = json_normalize(dict, 'StoreOpendate')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-186-40dc932c4021> in <module>
# ----> 1 df = json_normalize(dict, 'StoreOpendate')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\json\normalize.py in json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep)
#     265                 records.extend(recs)
#     266
# --> 267     _recursive_extract(data, record_path, {}, level=0)
#     268
#     269     result = DataFrame(records)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\json\normalize.py in _recursive_extract(data, path, seen_meta, level)
#     242         else:
#     243             for obj in data:
# --> 244                 recs = _pull_field(obj, path[0])
#     245
#     246                 # For repeating the metadata later
#
# ...

# %%
df = json_normalize(jo, 'StoreNo')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-96-3a88ec5f6b7f> in <module>
# ----> 1 df = json_normalize(jo, 'StoreNo')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\json\normalize.py in json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep)
#     265                 records.extend(recs)
#     266
# --> 267     _recursive_extract(data, record_path, {}, level=0)
#     268
#     269     result = DataFrame(records)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\json\normalize.py in _recursive_extract(data, path, seen_meta, level)
#     242         else:
#     243             for obj in data:
# --> 244                 recs = _pull_field(obj, path[0])
#     245
#     246                 # For repeating the metadata later
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\json\normalize.py in _pull_field(js, spec)
# ...

# %%
jo = json.loads(goo)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-111-95dc7c0d532c> in <module>
# ----> 1 jo = json.loads(goo)
#
# C:\ProgramData\Anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# C:\ProgramData\Anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# C:\ProgramData\Anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
# ...

# %%
goo=' '.join('"{}"'.format(word) for word in goo.split(' '))

# %%
''.join(goo.split())
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-52-c0862ce87dff> in <module>
#       1 ''.join(goo.split())
# ----> 2 jo = json.loads(goo)
#
# C:\ProgramData\Anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# C:\ProgramData\Anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     338         end = _w(s, end).end()
#     339         if end != len(s):
# --> 340             raise JSONDecodeError("Extra data", s, end)
#     341         return obj
#     342
#
# ...

# %%
jo = json.loads(goo)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-74-95dc7c0d532c> in <module>
# ----> 1 jo = json.loads(goo)
#
# C:\ProgramData\Anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# C:\ProgramData\Anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     338         end = _w(s, end).end()
#     339         if end != len(s):
# --> 340             raise JSONDecodeError("Extra data", s, end)
#     341         return obj
#     342
#
# JSONDecodeError: Extra data: line 1 column 6 (char 5)

# %%
df = json_normalize(jo, 'list')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-72-daae32869443> in <module>
# ----> 1 df = json_normalize(jo, 'list')
#
# NameError: name 'jo' is not defined

# %%
import requests
import json
from bs4 import BeautifulSoup as BS
url = 'https://www.coffeebeankorea.com/store/store_data2.asp?lat=&lng=&chk1=0&chk2=0&chk3=0&chk4=0&chk5=0&chk6=0&chk7=0&chk8=0&chk9=0&keyword=&StoreLocal=%EC%84%9C%EC%9A%B8&StoreLocal2=&storeNo='
json_string = requests.get(url).text
# jsonString = json.dumps(json_string, ensure_ascii=False)
storelist=json.loads(json_string)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-196-2a6ac631c05a> in <module>
#       4 url = 'https://www.coffeebeankorea.com/store/store_data2.asp?lat=&lng=&chk1=0&chk2=0&chk3=0&chk4=0&chk5=0&chk6=0&chk7=0&chk8=0&chk9=0&keyword=&StoreLocal=%EC%84%9C%EC%9A%B8&StoreLocal2=&storeNo='
#       5 json_string = requests.get(url).text
# ----> 6 json_string = json_string.decode('utf-8')
#       7 # jsonString = json.dumps(json_string, ensure_ascii=False)
#       8 storelist=json.loads(json_string)
#
# AttributeError: 'str' object has no attribute 'decode'

# %%
import requests
from bs4 import BeautifulSoup

# 1) reqeusts 라이브러리를 활용한 HTML 페이지 요청 
# 1-1) res 객체에 HTML 데이터가 저장되고, res.content로 데이터를 추출할 수 있음
res = requests.get('http://v.media.daum.net/v/20170615203441266')

# print(res.content)
# 2) HTML 페이지 파싱 BeautifulSoup(HTML데이터, 파싱방법)
# 2-1) BeautifulSoup 파싱방법
soup = BeautifulSoup(res.content, 'html.parser')

# 3) 필요한 데이터 검색
title = soup.find('title')

# 4) 필요한 데이터 추출
print(title.get_text())
